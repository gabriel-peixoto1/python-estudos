# %% [markdown]
# 1. Faça um programa que tenha uma função chamada amplitude. A função deve receber uma lista e imprimir a amplitude.
# Crie também um código para testar sua função

# %%
l1 = int(input('Insira um item da lista: '))
l2 = int(input('Insira um item da lista: '))
l3 = int(input('Insira um item da lista: '))
l4 = int(input('Insira um item da lista: '))
l5 = int(input('Insira um item da lista: '))
l6 = int(input('Insira um item da lista: '))

lst = [l1,l2,l3,l4,l5,l6]

def amplitude(n):
    return max(n) - min(n)

print ('A amplitude é: ',amplitude(lst))
# Out:
# Insira um item da lista:  5
# Insira um item da lista:  8
# Insira um item da lista:  97
# Insira um item da lista:  66
# Insira um item da lista:  12
# Insira um item da lista:  89
# A amplitude é:  92

# %% [markdown]
# 2. Faça uma função que receba uma string e imprima esta string na forma vertical

# %%
text = str(input('Insira uma palavra: '))

for i in range (0,len(text)):
    print((text[i]))
# Out:
# Insira uma palavra:  GABRIEL
# G
# A
# B
# R
# I
# E
# L

# %% [markdown]
# 3. Crie um programa que leia o peso de uma carga em números inteiros.
# Se o peso for até 10 kg, informe que o valor será de R$ 50,00. Entre 11 e 20 kg, informe que o valor será de R$ 80. Se for maior que  20 informe que o transporte não é aceito. Teste vários pesos.

# %%
p = int(input('Informe o peso da carga: '))

if p <= 10:
    print('o valor será de R$50,00.')
elif p >= 11 and p <= 20:
    print('o valor será de R$80,00.')
else: 
    print(
