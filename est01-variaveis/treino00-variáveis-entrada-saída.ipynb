# %%
#testando o uso de variáveis inteiras, decimais, strings e print.
a = 10.2
b = 25
c = 50
d = (a*b/c + 12)
print('aconteceu', d, 'vezes, mas ainda assim', b, 'ocorrências')
#obs.: erro "inigualável" me trouxe problemas por causa de um parentêse extra.
#NÃO LÊ VÍRGULA EM NÚMEROS CONTÍNUOS. PRECISA SER PONTO.
#float = ponto flutuante
# Out:
# aconteceu 17.1 vezes, mas ainda assim 25 ocorrências

# %%
#testando agora com um valor constante (string)
print("testando mais um")
# Out:
# testando mais um

# %%
x = 100000000

y = 'djonga'

print(type(x),type(y)) #type me ajuda a ter o tipo da variável.
# Out:
# <class 'int'> <class 'str'>

# %%
#input com string
w = input("informe um valor, agora:")
print("retorno", w, "igual")
# Out:
# informe um valor, agora: 50
# retorno 50 igual

# %%
#input com int e input com float
w = int(input('um valor:  '))
y = float(input('outro valor:   '))
print('o dobro da soma:  ',(w+y)*2)
#a categorização da variável tem que sempre vir antes do input.
# Out:
# um valor:   5
# outro valor:    4
# o dobro da soma:   18.0

# %%
#transformando números em texto

x = str(input('escreva um número, e o escreverei:'))
print(x)

#não funcionou bem como eu pensava.
# Out:
# escreva um número, e o escreverei: 50
# 50
