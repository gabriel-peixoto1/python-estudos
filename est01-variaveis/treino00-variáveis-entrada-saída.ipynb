# %%
#testando o uso de variáveis inteiras, decimais, strings e print.
cu = 10.2
bct = 25
lolo = 50
crlh = (cu*bct/lolo + 12)
print('dei o cu', crlh, 'vezes, mas comi', bct, 'mulheres no mesmo dia.')
#obs.: erro "inigualável" me encheu o saco por causa de um parentêse extra.
#NÃO LÊ VÍRGULA EM NÚMEROS CONTÍNUOS. PRECISA SER PONTO.
#float = ponto flutuante
# Out:
# dei o cu 17.1 vezes, mas comi 25 mulheres no mesmo dia.

# %%
#testando agora com um valor constante (string)
print("essa mulher é foda")
# Out:
# essa mulher é foda

# %%
x = 100000000

y = 'djonga'

print(type(x),type(y)) #type me ajuda a ter o tipo da variável.
# Out:
# <class 'int'> <class 'str'>

# %%
#input com string
w = input("informe um valor, seu merda:")
print("toma de volta seu", w, "porra")
# Out:
# informe um valor, seu merda:ok
# toma de volta seu ok porra

# %%
#input com int e input com float
w = int(input('fala valor, fala:  '))
y = float(input('fala quebrado:   '))
print('toma aqui o dobro da soma:  ',(w+y)*2)
#a categorização da variável tem que sempre vir antes do input.
# Out:
# fala valor, fala:  50
# fala quebrado:   50.2
# toma aqui o dobro da soma:   200.4

# %%
#transformando números em texto

x = str(input('escreva um número, e o escreverei:'))
print(x)

#não funcionou bem como eu pensava kkkkk
# Out:
# escreva um número, e o escreverei:cinquenta
# cinquenta
